# %% [markdown]
# **Import necessary libraries**

# %%
import torch
import torchvision
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import random
import os
from torch.utils.data import Dataset, DataLoader, random_split, Subset
from sklearn.model_selection import train_test_split
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Compose, Normalize
from torchvision.datasets import MNIST
from PIL import Image
from torchvision.models.feature_extraction import create_feature_extractor
from sklearn.metrics import precision_score, recall_score, roc_auc_score, confusion_matrix, multilabel_confusion_matrix
from sklearn.preprocessing import label_binarize

# %%
# Use GPU if available, else use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# **Data Loading and Preprocessing**

# %%
# Original transformation
original_transform = transforms.Compose([
    transforms.Resize((224, 224)),  
    transforms.ToTensor(),  
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  
])

# Augmented transformation with horizontal flip and random rotation
augmented_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=1.0), 
    # Randomly rotate images in the range (-15, 15) degrees
    transforms.RandomRotation(degrees=15),   
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
# Load the dataset from the directory
raw_dataset = datasets.ImageFolder(root='dataset', transform=None)

# Kaggle version
# Load the dataset without applying transformations
#raw_dataset = datasets.ImageFolder(root='/kaggle/input/the-iqothnccd-lung-cancer-dataset', transform=None)

# Access a raw image and its label directly
raw_img, label = raw_dataset[0]

# Now apply the transformations to the raw PIL image for demonstration
img_original_tensor = original_transform(raw_img)
img_augmented_tensor = augmented_transform(raw_img)

# %%
# Access the raw image and its label from dataset
img, label = raw_dataset[0]

# Define the function to unnormalize and show the image
def show_image(img, title=None, ax=None):
    img = img.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    img = std * img + mean  
    img = np.clip(img, 0, 1)
    if ax is not None:
        ax.imshow(img)
        if title is not None:
            ax.set_title(title)
        ax.axis('off')
    else:
        plt.imshow(img)
        if title is not None:
            plt.title(title)
        plt.pause(0.001)  

fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Displaying the original image and the augmented image
show_image(img_original_tensor, title='Original Image', ax=axs[0])
show_image(img_augmented_tensor, title='Augmented Image', ax=axs[1])

plt.show()

# %%
#dataset = datasets.ImageFolder(root='/kaggle/input/the-iqothnccd-lung-cancer-dataset', transform=augmented_transform)
dataset = datasets.ImageFolder(root='dataset', transform=augmented_transform)


# Splitting the dataset
train_size = int(0.7 * len(dataset)) 
val_size = int(0.15 * len(dataset)) 
test_size = len(dataset) - train_size - val_size 

# Extracting labels from the dataset
targets = [s[1] for s in dataset.samples]  

# Splitting the dataset into train+val and test sets
train_val_idx, test_idx = train_test_split(
    range(len(targets)),
    test_size=test_size / len(dataset),  
    stratify=targets,
    random_state=42  
)

# Splitting train+val into training and validation sets
train_idx, val_idx = train_test_split(
    train_val_idx,
    test_size=val_size / (train_size + val_size),  
    stratify=[targets[i] for i in train_val_idx],
    random_state=42  
)

# Creating subsets for each split
train_dataset = Subset(dataset, train_idx)
validation_dataset = Subset(dataset, val_idx)
test_dataset = Subset(dataset, test_idx)

# Creating data loaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
validation_loader = DataLoader(validation_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %% [markdown]
# **Define the CNN Model**

# %%
class CNN_for_LungCancer(nn.Module):
    def __init__(self, dropout_rate, fc_units):
        super(CNN_for_LungCancer, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)  
        self.act1 = nn.ReLU()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout1 = nn.Dropout(dropout_rate)  
        
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)  
        self.act2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout_rate)   

        self.fc1 = nn.Linear(in_features=64 * 56 * 56, out_features=fc_units)
        self.fc2 = nn.Linear(fc_units, 3)
        self.dropout3 = nn.Dropout(dropout_rate)


    def forward(self, x):
        x = self.pool(self.bn1(self.act1(self.conv1(x))))
        x = self.dropout1(x)
        x = self.pool(self.bn2(self.act2(self.conv2(x))))
        x = self.dropout2(x)
        x = torch.flatten(x, 1)
        x = self.dropout3(self.fc1(x))
        x = self.fc2(x)

        return x

# %% [markdown]
# **Initialize CNN Model**

# %%
model = CNN_for_LungCancer(dropout_rate=0.25, fc_units=64)
model.to(device)
# Out:
# CNN_for_LungCancer(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): ReLU()
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act2): ReLU()
#   (dropout2): Dropout(p=0.25, inplace=False)
#   (fc1): Linear(in_features=200704, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=3, bias=True)
#   (dropout3): Dropout(p=0.25, inplace=False)
# )

# %% [markdown]
# **Train and evaluate the model (Single trial)**

# %%
# Initialize lists to store accuracies and losses
train_accuracies = []
test_accuracies = []
validation_accuracies = []

train_losses = []
test_losses = []
validation_losses = []

# %%
def train_and_evaluate(model, train_loader, validation_loader, test_loader, epochs=10, lr=0.0001):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    # Initialize Optimizer and Loss Function
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), 
                           lr=lr,
                           weight_decay=1e-4, 
                           betas=(0.9, 0.999),
                           eps=1e-8,
                           amsgrad=True)
    
    for epoch in range(epochs):
        # Training phase
        model.train()
        train_loss = 0
        correct_train = 0
        total_train = 0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_accuracy = 100 * correct_train / total_train
        train_accuracies.append(train_accuracy)
        train_losses.append(train_loss / len(train_loader))

        # Validation phase
        model.eval()
        correct_validation = 0
        total_validation = 0
        validation_loss = 0
        with torch.no_grad():
            for inputs, labels in validation_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                validation_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()

        validation_accuracy = 100 * correct_validation / total_validation
        validation_accuracies.append(validation_accuracy)
        validation_losses.append(validation_loss / len(validation_loader))

        # Evaluate on the test set
        test_loss = 0 
        correct_test = 0
        total_test = 0
        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                test_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total_test += labels.size(0)
                correct_test += (predicted == labels).sum().item()

        test_accuracy = 100 * correct_test / total_test
        test_accuracies.append(test_accuracy)
        test_losses.append(test_loss / len(test_loader))

        print(f"Epoch {epoch+1}, Train Loss: {train_loss/len(train_loader):.4f}, "
              f"Validation Loss: {validation_loss/len(validation_loader):.4f}, "
              f"Test Loss: {test_loss/len(test_loader):.4f}, "
              f"Train Accuracy: {train_accuracy:.2f}%, "
              f"Validation Accuracy: {validation_accuracy:.2f}%, "
              f"Test Accuracy: {test_accuracy:.2f}%")
        print("--------------------------------------------------------------")

# %%
train_and_evaluate(model, train_loader, validation_loader, test_loader, epochs=10, lr=1e-4)
# Out:
# Epoch 1, Train Loss: 0.8135, Validation Loss: 2.8022, Test Loss: 2.6395, Train Accuracy: 91.92%, Validation Accuracy: 73.78%, Test Accuracy: 81.93%
# --------------------------------------------------------------
# Epoch 2, Train Loss: 0.6698, Validation Loss: 4.0222, Test Loss: 2.4758, Train Accuracy: 93.48%, Validation Accuracy: 71.34%, Test Accuracy: 79.52%
# --------------------------------------------------------------
# Epoch 3, Train Loss: 0.8259, Validation Loss: 4.9919, Test Loss: 4.4799, Train Accuracy: 91.79%, Validation Accuracy: 71.95%, Test Accuracy: 74.10%
# --------------------------------------------------------------
# Epoch 4, Train Loss: 0.6056, Validation Loss: 2.8084, Test Loss: 2.1041, Train Accuracy: 94.26%, Validation Accuracy: 79.88%, Test Accuracy: 83.13%
# --------------------------------------------------------------
# Epoch 5, Train Loss: 0.5068, Validation Loss: 1.2162, Test Loss: 1.0655, Train Accuracy: 95.18%, Validation Accuracy: 86.59%, Test Accuracy: 86.75%
# --------------------------------------------------------------
# Epoch 6, Train Loss: 0.6804, Validation Loss: 4.3523, Test Loss: 4.9806, Train Accuracy: 94.13%, Validation Accuracy: 75.00%, Test Accuracy: 68.67%
# --------------------------------------------------------------
# Epoch 7, Train Loss: 0.4826, Validation Loss: 3.5455, Test Loss: 3.2704, Train Accuracy: 95.31%, Validation Accuracy: 78.66%, Test Accuracy: 77.11%
# --------------------------------------------------------------
# Epoch 8, Train Loss: 0.3795, Validation Loss: 3.8795, Test Loss: 3.1213, Train Accuracy: 97.26%, Validation Accuracy: 75.61%, Test Accuracy: 75.90%
# --------------------------------------------------------------
# Epoch 9, Train Loss: 0.1990, Validation Loss: 4.1404, Test Loss: 3.5597, Train Accuracy: 97.91%, Validation Accuracy: 75.61%, Test Accuracy: 78.31%
# --------------------------------------------------------------
# Epoch 10, Train Loss: 0.2428, Validation Loss: 1.4817, Test Loss: 1.5042, Train Accuracy: 97.52%, Validation Accuracy: 82.93%, Test Accuracy: 87.35%
# --------------------------------------------------------------

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(test_accuracies, label='Test Accuracy')
plt.plot(validation_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training and Test Accuracies')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Losses')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Hyperparameter Search**

# %%
hyperparameters = {
    'learning_rate': [1e-3, 1e-4, 1e-5],
    'dropout_rate': [0.25, 0.5, 0.75],
    'fc_units': [64, 128, 256]
}

# %%
def random_search(hyperparameters, num_trials, base_save_path='models'):
    if not os.path.exists(base_save_path):
        os.makedirs(base_save_path)

    results = []
    best_validation_accuracy = 0
    best_model_path = ""

    for trial in range(num_trials):
        # Randomly sample hyperparameters
        lr = random.choice(hyperparameters['learning_rate'])
        dropout = random.choice(hyperparameters['dropout_rate'])
        fc_units = random.choice(hyperparameters['fc_units'])
        
        # Define save path for the current trial's best model
        save_path = os.path.join(base_save_path, f'best_model_trial_{trial+1}.pt')
        
        # Initialize and train the model
        print(f"Trial {trial+1}: Training with lr={lr}, dropout={dropout}, fc_units={fc_units}")
        model = CNN_for_LungCancer(dropout_rate=dropout, fc_units=fc_units)
        metrics = train_and_evaluate_new(model, train_loader, validation_loader, test_loader, epochs=10, lr=lr, save_path=save_path)
        
        # Append metrics to results list
        results.append(metrics)
        
        # Update the path of the best model if the current model performence is better
        if metrics['best_validation_accuracy'] > best_validation_accuracy:
            best_validation_accuracy = metrics['best_validation_accuracy']
            best_model_path = metrics['save_path']
    
    print(f"Best model saved at: {best_model_path}")
    return results, best_model_path

# %%
def train_and_evaluate_new(model, train_loader, validation_loader, test_loader, epochs=10, lr=0.0001, save_path='best_model.pt'):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), 
                           lr=lr, 
                           weight_decay=1e-4, 
                           betas=(0.9, 0.999), 
                           eps=1e-8, 
                           amsgrad=True)
    
    best_validation_accuracy = 0  
    
    # Initialize metrics storage
    metrics = {
        'best_validation_accuracy': 0,
        'best_validation_loss': float('inf'),
        'corresponding_test_accuracy': 0,
        'corresponding_test_loss': float('inf'),
        'final_train_accuracy': 0,
        'final_train_loss': float('inf'),
    }

    for epoch in range(epochs):
        model.train()
        train_loss = 0
        correct_train = 0
        total_train = 0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        # Compute training metrics
        train_accuracy = 100 * correct_train / total_train
        train_loss_avg = train_loss / len(train_loader)

        model.eval()
        validation_loss = 0
        correct_validation = 0
        total_validation = 0
        with torch.no_grad():
            for inputs, labels in validation_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                validation_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()

        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss_avg = validation_loss / len(validation_loader)

        test_loss = 0
        correct_test = 0
        total_test = 0
        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                test_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total_test += labels.size(0)
                correct_test += (predicted == labels).sum().item()

        test_accuracy = 100 * correct_test / total_test
        test_loss_avg = test_loss / len(test_loader)

        # Update metrics if better validation accuracy is found
        if validation_accuracy > best_validation_accuracy:
            best_validation_accuracy = validation_accuracy
            # Save the model weights
            torch.save(model.state_dict(), save_path)
            # Update metrics with the new best values
            metrics.update({
                'best_validation_accuracy': validation_accuracy,
                'best_validation_loss': validation_loss_avg,
                'corresponding_test_accuracy': test_accuracy,
                'corresponding_test_loss': test_loss_avg,
            })

        # Always update these metrics after each epoch
        metrics.update({
            'final_train_accuracy': train_accuracy,
            'final_train_loss': train_loss_avg,
        })

        print(f"Epoch {epoch+1}, Train Loss: {train_loss_avg:.4f}, "
              f"Validation Loss: {validation_loss_avg:.4f}, "
              f"Test Loss: {test_loss_avg:.4f}, "
              f"Train Accuracy: {train_accuracy:.2f}%, "
              f"Validation Accuracy: {validation_accuracy:.2f}%, "
              f"Test Accuracy: {test_accuracy:.2f}%")
        print("--------------------------------------------------------------")
    
    # After the loop, save the path in metrics for reference
    metrics['save_path'] = save_path
    return metrics

# %%
results, best_model_path = random_search(hyperparameters, num_trials=10)
# Out:
# Trial 1: Training with lr=0.001, dropout=0.25, fc_units=64
# Epoch 1, Train Loss: 56.0996, Validation Loss: 10.7318, Test Loss: 7.7750, Train Accuracy: 60.89%, Validation Accuracy: 73.17%, Test Accuracy: 75.30%
# --------------------------------------------------------------
# Epoch 2, Train Loss: 10.6332, Validation Loss: 18.3972, Test Loss: 13.9218, Train Accuracy: 78.75%, Validation Accuracy: 70.73%, Test Accuracy: 74.10%
# --------------------------------------------------------------
# Epoch 3, Train Loss: 9.1124, Validation Loss: 9.5035, Test Loss: 8.2478, Train Accuracy: 82.01%, Validation Accuracy: 82.32%, Test Accuracy: 83.13%
# --------------------------------------------------------------
# Epoch 4, Train Loss: 5.5361, Validation Loss: 9.5063, Test Loss: 8.1323, Train Accuracy: 86.96%, Validation Accuracy: 77.44%, Test Accuracy: 78.92%
# --------------------------------------------------------------
# Epoch 5, Train Loss: 2.7232, Validation Loss: 2.3574, Test Loss: 2.5974, Train Accuracy: 92.57%, Validation Accuracy: 88.41%, Test Accuracy: 90.36%
# --------------------------------------------------------------
# Epoch 6, Train Loss: 2.4599, Validation Loss: 4.1344, Test Loss: 2.6794, Train Accuracy: 91.00%, Validation Accuracy: 88.41%, Test Accuracy: 92.17%
# --------------------------------------------------------------
# Epoch 7, Train Loss: 2.0155, Validation Loss: 2.9827, Test Loss: 2.9796, Train Accuracy: 92.31%, Validation Accuracy: 91.46%, Test Accuracy: 88.55%
# --------------------------------------------------------------
# Epoch 8, Train Loss: 1.7340, Validation Loss: 1.2947, Test Loss: 1.0281, Train Accuracy: 93.22%, Validation Accuracy: 92.68%, Test Accuracy: 94.58%
# --------------------------------------------------------------
# Epoch 9, Train Loss: 1.8254, Validation Loss: 5.5940, Test Loss: 6.1083, Train Accuracy: 92.70%, Validation Accuracy: 85.37%, Test Accuracy: 81.93%
# --------------------------------------------------------------
# Epoch 10, Train Loss: 0.8710, Validation Loss: 1.0161, Test Loss: 1.6016, Train Accuracy: 95.18%, Validation Accuracy: 92.68%, Test Accuracy: 93.37%
# --------------------------------------------------------------
# Trial 2: Training with lr=0.001, dropout=0.5, fc_units=256
# Epoch 1, Train Loss: 69.1777, Validation Loss: 21.3966, Test Loss: 29.7376, Train Accuracy: 59.84%, Validation Accuracy: 64.63%, Test Accuracy: 63.86%
# --------------------------------------------------------------
# Epoch 2, Train Loss: 25.3302, Validation Loss: 26.3261, Test Loss: 21.4848, Train Accuracy: 73.79%, Validation Accuracy: 76.22%, Test Accuracy: 74.10%
# --------------------------------------------------------------
# Epoch 3, Train Loss: 15.0587, Validation Loss: 10.4579, Test Loss: 9.5094, Train Accuracy: 82.40%, Validation Accuracy: 77.44%, Test Accuracy: 77.71%
# --------------------------------------------------------------
# Epoch 4, Train Loss: 9.9123, Validation Loss: 10.2176, Test Loss: 7.0835, Train Accuracy: 85.40%, Validation Accuracy: 79.27%, Test Accuracy: 86.75%
# --------------------------------------------------------------
# Epoch 5, Train Loss: 7.8556, Validation Loss: 7.7400, Test Loss: 3.7643, Train Accuracy: 87.87%, Validation Accuracy: 85.37%, Test Accuracy: 87.95%
# --------------------------------------------------------------
# Epoch 6, Train Loss: 5.2427, Validation Loss: 14.8059, Test Loss: 8.2996, Train Accuracy: 89.31%, Validation Accuracy: 73.17%, Test Accuracy: 83.13%
# --------------------------------------------------------------
# Epoch 7, Train Loss: 5.4341, Validation Loss: 5.4854, Test Loss: 5.3944, Train Accuracy: 89.70%, Validation Accuracy: 85.98%, Test Accuracy: 89.76%
# --------------------------------------------------------------
# Epoch 8, Train Loss: 4.6853, Validation Loss: 3.6247, Test Loss: 2.1241, Train Accuracy: 92.05%, Validation Accuracy: 92.07%, Test Accuracy: 92.77%
# --------------------------------------------------------------
# Epoch 9, Train Loss: 4.9903, Validation Loss: 10.1381, Test Loss: 4.2250, Train Accuracy: 89.83%, Validation Accuracy: 79.27%, Test Accuracy: 88.55%
# --------------------------------------------------------------
# Epoch 10, Train Loss: 4.4817, Validation Loss: 19.1865, Test Loss: 16.9477, Train Accuracy: 91.79%, Validation Accuracy: 76.83%, Test Accuracy: 76.51%
# --------------------------------------------------------------
# Trial 3: Training with lr=0.0001, dropout=0.25, fc_units=64
# Epoch 1, Train Loss: 8.1790, Validation Loss: 2.3123, Test Loss: 2.7875, Train Accuracy: 59.84%, Validation Accuracy: 71.34%, Test Accuracy: 74.10%
# --------------------------------------------------------------
# Epoch 2, Train Loss: 1.7380, Validation Loss: 3.0023, Test Loss: 3.3285, Train Accuracy: 82.92%, Validation Accuracy: 67.07%, Test Accuracy: 68.07%
# --------------------------------------------------------------
# Epoch 3, Train Loss: 1.4867, Validation Loss: 5.6241, Test Loss: 6.0600, Train Accuracy: 85.14%, Validation Accuracy: 59.76%, Test Accuracy: 59.64%
# --------------------------------------------------------------
# Epoch 4, Train Loss: 0.9108, Validation Loss: 3.8804, Test Loss: 4.2032, Train Accuracy: 90.09%, Validation Accuracy: 61.59%, Test Accuracy: 64.46%
# --------------------------------------------------------------
# Epoch 5, Train Loss: 0.7525, Validation Loss: 5.8090, Test Loss: 6.0838, Train Accuracy: 91.92%, Validation Accuracy: 62.20%, Test Accuracy: 58.43%
# --------------------------------------------------------------
# Epoch 6, Train Loss: 0.5548, Validation Loss: 4.5036, Test Loss: 3.7426, Train Accuracy: 92.70%, Validation Accuracy: 67.07%, Test Accuracy: 65.06%
# --------------------------------------------------------------
# Epoch 7, Train Loss: 0.7397, Validation Loss: 4.4386, Test Loss: 3.9322, Train Accuracy: 91.66%, Validation Accuracy: 66.46%, Test Accuracy: 60.24%
# --------------------------------------------------------------
# Epoch 8, Train Loss: 0.6238, Validation Loss: 4.7767, Test Loss: 4.9254, Train Accuracy: 92.70%, Validation Accuracy: 68.29%, Test Accuracy: 61.45%
# --------------------------------------------------------------
# Epoch 9, Train Loss: 0.5171, Validation Loss: 4.9298, Test Loss: 5.4812, Train Accuracy: 93.22%, Validation Accuracy: 70.12%, Test Accuracy: 63.86%
# --------------------------------------------------------------
# Epoch 10, Train Loss: 0.4952, Validation Loss: 5.6506, Test Loss: 4.9166, Train Accuracy: 94.13%, Validation Accuracy: 65.85%, Test Accuracy: 63.25%
# --------------------------------------------------------------
# Trial 4: Training with lr=1e-05, dropout=0.5, fc_units=128
# Epoch 1, Train Loss: 1.3202, Validation Loss: 0.9584, Test Loss: 0.9832, Train Accuracy: 57.50%, Validation Accuracy: 50.00%, Test Accuracy: 51.20%
# --------------------------------------------------------------
# Epoch 2, Train Loss: 0.7411, Validation Loss: 0.8469, Test Loss: 0.8967, Train Accuracy: 73.79%, Validation Accuracy: 60.98%, Test Accuracy: 60.24%
# --------------------------------------------------------------
# Epoch 3, Train Loss: 0.5161, Validation Loss: 0.7648, Test Loss: 0.7410, Train Accuracy: 80.31%, Validation Accuracy: 67.07%, Test Accuracy: 65.66%
# --------------------------------------------------------------
# Epoch 4, Train Loss: 0.4817, Validation Loss: 0.9968, Test Loss: 0.9343, Train Accuracy: 82.14%, Validation Accuracy: 57.93%, Test Accuracy: 57.23%
# --------------------------------------------------------------
# Epoch 5, Train Loss: 0.4463, Validation Loss: 0.8129, Test Loss: 0.8394, Train Accuracy: 82.27%, Validation Accuracy: 68.90%, Test Accuracy: 66.87%
# --------------------------------------------------------------
# Epoch 6, Train Loss: 0.3817, Validation Loss: 0.7533, Test Loss: 0.6801, Train Accuracy: 85.66%, Validation Accuracy: 66.46%, Test Accuracy: 71.08%
# --------------------------------------------------------------
# Epoch 7, Train Loss: 0.3485, Validation Loss: 0.7498, Test Loss: 0.7401, Train Accuracy: 87.35%, Validation Accuracy: 69.51%, Test Accuracy: 70.48%
# --------------------------------------------------------------
# Epoch 8, Train Loss: 0.4141, Validation Loss: 0.6713, Test Loss: 0.6184, Train Accuracy: 85.92%, Validation Accuracy: 73.17%, Test Accuracy: 76.51%
# --------------------------------------------------------------
# Epoch 9, Train Loss: 0.3183, Validation Loss: 0.7341, Test Loss: 0.6574, Train Accuracy: 87.74%, Validation Accuracy: 72.56%, Test Accuracy: 71.08%
# --------------------------------------------------------------
# Epoch 10, Train Loss: 0.2161, Validation Loss: 0.7587, Test Loss: 0.6987, Train Accuracy: 92.31%, Validation Accuracy: 69.51%, Test Accuracy: 72.29%
# --------------------------------------------------------------
# Trial 5: Training with lr=1e-05, dropout=0.5, fc_units=256
# Epoch 1, Train Loss: 1.2177, Validation Loss: 1.4242, Test Loss: 1.5313, Train Accuracy: 59.06%, Validation Accuracy: 49.39%, Test Accuracy: 44.58%
# --------------------------------------------------------------
# Epoch 2, Train Loss: 0.8251, Validation Loss: 1.1766, Test Loss: 1.2966, Train Accuracy: 73.79%, Validation Accuracy: 54.88%, Test Accuracy: 49.40%
# --------------------------------------------------------------
# Epoch 3, Train Loss: 0.6854, Validation Loss: 1.1728, Test Loss: 1.0793, Train Accuracy: 76.92%, Validation Accuracy: 54.27%, Test Accuracy: 59.04%
# --------------------------------------------------------------
# Epoch 4, Train Loss: 0.4972, Validation Loss: 1.1227, Test Loss: 1.1295, Train Accuracy: 82.79%, Validation Accuracy: 53.66%, Test Accuracy: 56.02%
# --------------------------------------------------------------
# Epoch 5, Train Loss: 0.5353, Validation Loss: 0.8987, Test Loss: 0.9288, Train Accuracy: 84.75%, Validation Accuracy: 62.20%, Test Accuracy: 62.05%
# --------------------------------------------------------------
# Epoch 6, Train Loss: 0.3362, Validation Loss: 1.1406, Test Loss: 1.2286, Train Accuracy: 87.87%, Validation Accuracy: 59.15%, Test Accuracy: 61.45%
# --------------------------------------------------------------
# Epoch 7, Train Loss: 0.3996, Validation Loss: 1.2950, Test Loss: 1.3237, Train Accuracy: 87.09%, Validation Accuracy: 60.98%, Test Accuracy: 59.04%
# --------------------------------------------------------------
# Epoch 8, Train Loss: 0.4042, Validation Loss: 1.2570, Test Loss: 1.3528, Train Accuracy: 86.31%, Validation Accuracy: 62.20%, Test Accuracy: 59.64%
# --------------------------------------------------------------
# Epoch 9, Train Loss: 0.3891, Validation Loss: 1.6003, Test Loss: 1.5615, Train Accuracy: 86.96%, Validation Accuracy: 55.49%, Test Accuracy: 54.22%
# --------------------------------------------------------------
# Epoch 10, Train Loss: 0.3136, Validation Loss: 1.0338, Test Loss: 0.9035, Train Accuracy: 89.96%, Validation Accuracy: 60.98%, Test Accuracy: 67.47%
# --------------------------------------------------------------
# Trial 6: Training with lr=0.0001, dropout=0.25, fc_units=128
# Epoch 1, Train Loss: 7.4481, Validation Loss: 2.2436, Test Loss: 1.7449, Train Accuracy: 65.45%, Validation Accuracy: 71.95%, Test Accuracy: 72.29%
# --------------------------------------------------------------
# Epoch 2, Train Loss: 2.5333, Validation Loss: 3.0359, Test Loss: 3.2376, Train Accuracy: 81.10%, Validation Accuracy: 74.39%, Test Accuracy: 74.70%
# --------------------------------------------------------------
# Epoch 3, Train Loss: 1.5721, Validation Loss: 4.0293, Test Loss: 2.9478, Train Accuracy: 86.96%, Validation Accuracy: 67.68%, Test Accuracy: 71.69%
# --------------------------------------------------------------
# Epoch 4, Train Loss: 0.9554, Validation Loss: 7.0008, Test Loss: 6.1299, Train Accuracy: 91.00%, Validation Accuracy: 59.15%, Test Accuracy: 59.04%
# --------------------------------------------------------------
# Epoch 5, Train Loss: 1.3742, Validation Loss: 7.2161, Test Loss: 7.4152, Train Accuracy: 90.74%, Validation Accuracy: 54.27%, Test Accuracy: 54.22%
# --------------------------------------------------------------
# Epoch 6, Train Loss: 0.9846, Validation Loss: 9.3701, Test Loss: 6.5554, Train Accuracy: 91.92%, Validation Accuracy: 56.71%, Test Accuracy: 59.04%
# --------------------------------------------------------------
# Epoch 7, Train Loss: 0.9394, Validation Loss: 7.8108, Test Loss: 6.1382, Train Accuracy: 92.70%, Validation Accuracy: 54.88%, Test Accuracy: 63.25%
# --------------------------------------------------------------
# Epoch 8, Train Loss: 1.2036, Validation Loss: 9.7665, Test Loss: 10.0540, Train Accuracy: 92.44%, Validation Accuracy: 60.37%, Test Accuracy: 56.02%
# --------------------------------------------------------------
# Epoch 9, Train Loss: 0.7805, Validation Loss: 10.5855, Test Loss: 10.9620, Train Accuracy: 94.26%, Validation Accuracy: 57.32%, Test Accuracy: 58.43%
# --------------------------------------------------------------
# Epoch 10, Train Loss: 0.6944, Validation Loss: 6.8982, Test Loss: 5.4662, Train Accuracy: 94.65%, Validation Accuracy: 58.54%, Test Accuracy: 63.25%
# --------------------------------------------------------------
# Trial 7: Training with lr=0.0001, dropout=0.75, fc_units=128
# Epoch 1, Train Loss: 9.0196, Validation Loss: 8.2173, Test Loss: 8.4392, Train Accuracy: 50.20%, Validation Accuracy: 39.63%, Test Accuracy: 39.76%
# --------------------------------------------------------------
# Epoch 2, Train Loss: 6.1745, Validation Loss: 9.0511, Test Loss: 9.8609, Train Accuracy: 58.67%, Validation Accuracy: 39.63%, Test Accuracy: 39.76%
# --------------------------------------------------------------
# Epoch 3, Train Loss: 5.5682, Validation Loss: 10.9955, Test Loss: 10.7870, Train Accuracy: 67.67%, Validation Accuracy: 40.85%, Test Accuracy: 43.37%
# --------------------------------------------------------------
# Epoch 4, Train Loss: 3.6150, Validation Loss: 9.9474, Test Loss: 9.5197, Train Accuracy: 73.66%, Validation Accuracy: 40.24%, Test Accuracy: 45.78%
# --------------------------------------------------------------
# Epoch 5, Train Loss: 3.1644, Validation Loss: 9.8758, Test Loss: 9.8556, Train Accuracy: 72.23%, Validation Accuracy: 41.46%, Test Accuracy: 45.18%
# --------------------------------------------------------------
# Epoch 6, Train Loss: 4.1321, Validation Loss: 9.1588, Test Loss: 9.0821, Train Accuracy: 72.10%, Validation Accuracy: 41.46%, Test Accuracy: 44.58%
# --------------------------------------------------------------
# Epoch 7, Train Loss: 2.7366, Validation Loss: 7.4058, Test Loss: 7.2611, Train Accuracy: 77.84%, Validation Accuracy: 46.34%, Test Accuracy: 45.78%
# --------------------------------------------------------------
# Epoch 8, Train Loss: 2.7219, Validation Loss: 8.3512, Test Loss: 7.4619, Train Accuracy: 79.14%, Validation Accuracy: 46.34%, Test Accuracy: 48.19%
# --------------------------------------------------------------
# Epoch 9, Train Loss: 2.2096, Validation Loss: 9.7467, Test Loss: 10.2274, Train Accuracy: 82.40%, Validation Accuracy: 45.12%, Test Accuracy: 44.58%
# --------------------------------------------------------------
# Epoch 10, Train Loss: 2.2673, Validation Loss: 10.3345, Test Loss: 10.1197, Train Accuracy: 83.44%, Validation Accuracy: 43.90%, Test Accuracy: 46.39%
# --------------------------------------------------------------
# Trial 8: Training with lr=0.001, dropout=0.5, fc_units=256
# Epoch 1, Train Loss: 60.8823, Validation Loss: 24.1301, Test Loss: 16.8876, Train Accuracy: 61.15%, Validation Accuracy: 75.00%, Test Accuracy: 76.51%
# --------------------------------------------------------------
# Epoch 2, Train Loss: 19.8088, Validation Loss: 36.1160, Test Loss: 38.2659, Train Accuracy: 77.05%, Validation Accuracy: 65.24%, Test Accuracy: 65.06%
# --------------------------------------------------------------
# Epoch 3, Train Loss: 14.6371, Validation Loss: 7.8003, Test Loss: 5.3523, Train Accuracy: 82.79%, Validation Accuracy: 78.66%, Test Accuracy: 85.54%
# --------------------------------------------------------------
# Epoch 4, Train Loss: 12.0873, Validation Loss: 13.0624, Test Loss: 10.0960, Train Accuracy: 83.83%, Validation Accuracy: 73.78%, Test Accuracy: 79.52%
# --------------------------------------------------------------
# Epoch 5, Train Loss: 11.0295, Validation Loss: 19.3540, Test Loss: 14.7062, Train Accuracy: 86.44%, Validation Accuracy: 70.73%, Test Accuracy: 78.92%
# --------------------------------------------------------------
# Epoch 6, Train Loss: 6.9865, Validation Loss: 13.2004, Test Loss: 10.4386, Train Accuracy: 89.57%, Validation Accuracy: 79.88%, Test Accuracy: 84.34%
# --------------------------------------------------------------
# Epoch 7, Train Loss: 3.2055, Validation Loss: 8.4248, Test Loss: 6.1926, Train Accuracy: 93.74%, Validation Accuracy: 82.93%, Test Accuracy: 82.53%
# --------------------------------------------------------------
# Epoch 8, Train Loss: 7.3599, Validation Loss: 4.2440, Test Loss: 1.8391, Train Accuracy: 86.31%, Validation Accuracy: 94.51%, Test Accuracy: 94.58%
# --------------------------------------------------------------
# Epoch 9, Train Loss: 5.7339, Validation Loss: 8.6309, Test Loss: 6.4179, Train Accuracy: 89.44%, Validation Accuracy: 82.93%, Test Accuracy: 84.94%
# --------------------------------------------------------------
# Epoch 10, Train Loss: 4.8052, Validation Loss: 3.4362, Test Loss: 5.1643, Train Accuracy: 91.26%, Validation Accuracy: 87.80%, Test Accuracy: 89.76%
# --------------------------------------------------------------
# Trial 9: Training with lr=0.0001, dropout=0.5, fc_units=256
# Epoch 1, Train Loss: 17.1086, Validation Loss: 11.9175, Test Loss: 13.4455, Train Accuracy: 53.19%, Validation Accuracy: 48.17%, Test Accuracy: 43.37%
# --------------------------------------------------------------
# Epoch 2, Train Loss: 4.1126, Validation Loss: 7.4106, Test Loss: 6.7151, Train Accuracy: 72.88%, Validation Accuracy: 51.83%, Test Accuracy: 50.60%
# --------------------------------------------------------------
# Epoch 3, Train Loss: 2.6928, Validation Loss: 5.6386, Test Loss: 4.7197, Train Accuracy: 81.88%, Validation Accuracy: 53.05%, Test Accuracy: 56.02%
# --------------------------------------------------------------
# Epoch 4, Train Loss: 1.9479, Validation Loss: 6.1022, Test Loss: 6.5753, Train Accuracy: 84.49%, Validation Accuracy: 53.05%, Test Accuracy: 53.61%
# --------------------------------------------------------------
# Epoch 5, Train Loss: 2.6564, Validation Loss: 10.3647, Test Loss: 11.1452, Train Accuracy: 82.01%, Validation Accuracy: 52.44%, Test Accuracy: 51.20%
# --------------------------------------------------------------
# Epoch 6, Train Loss: 1.4047, Validation Loss: 10.3947, Test Loss: 11.2230, Train Accuracy: 89.31%, Validation Accuracy: 48.17%, Test Accuracy: 50.60%
# --------------------------------------------------------------
# Epoch 7, Train Loss: 1.4206, Validation Loss: 7.6845, Test Loss: 8.6987, Train Accuracy: 89.70%, Validation Accuracy: 60.37%, Test Accuracy: 62.05%
# --------------------------------------------------------------
# Epoch 8, Train Loss: 1.7199, Validation Loss: 10.3905, Test Loss: 9.3722, Train Accuracy: 89.18%, Validation Accuracy: 50.61%, Test Accuracy: 56.02%
# --------------------------------------------------------------
# Epoch 9, Train Loss: 1.4995, Validation Loss: 8.9494, Test Loss: 8.6100, Train Accuracy: 90.35%, Validation Accuracy: 60.98%, Test Accuracy: 57.23%
# --------------------------------------------------------------
# Epoch 10, Train Loss: 1.3282, Validation Loss: 7.4971, Test Loss: 7.1162, Train Accuracy: 91.00%, Validation Accuracy: 62.20%, Test Accuracy: 59.64%
# --------------------------------------------------------------
# Trial 10: Training with lr=0.001, dropout=0.25, fc_units=64
# Epoch 1, Train Loss: 39.9031, Validation Loss: 10.0116, Test Loss: 8.8990, Train Accuracy: 58.80%, Validation Accuracy: 78.66%, Test Accuracy: 78.31%
# --------------------------------------------------------------
# Epoch 2, Train Loss: 10.4310, Validation Loss: 16.0378, Test Loss: 12.0361, Train Accuracy: 80.96%, Validation Accuracy: 74.39%, Test Accuracy: 77.11%
# --------------------------------------------------------------
# Epoch 3, Train Loss: 10.6673, Validation Loss: 14.3333, Test Loss: 13.9769, Train Accuracy: 81.75%, Validation Accuracy: 82.32%, Test Accuracy: 84.34%
# --------------------------------------------------------------
# Epoch 4, Train Loss: 8.8618, Validation Loss: 7.4494, Test Loss: 5.5798, Train Accuracy: 84.35%, Validation Accuracy: 81.71%, Test Accuracy: 82.53%
# --------------------------------------------------------------
# Epoch 5, Train Loss: 2.7576, Validation Loss: 4.9422, Test Loss: 4.6742, Train Accuracy: 91.66%, Validation Accuracy: 82.32%, Test Accuracy: 87.35%
# --------------------------------------------------------------
# Epoch 6, Train Loss: 1.6563, Validation Loss: 4.5760, Test Loss: 3.9124, Train Accuracy: 93.48%, Validation Accuracy: 78.05%, Test Accuracy: 82.53%
# --------------------------------------------------------------
# Epoch 7, Train Loss: 1.2895, Validation Loss: 4.7526, Test Loss: 5.6097, Train Accuracy: 94.26%, Validation Accuracy: 81.10%, Test Accuracy: 80.72%
# --------------------------------------------------------------
# Epoch 8, Train Loss: 1.1327, Validation Loss: 1.0828, Test Loss: 0.9558, Train Accuracy: 93.87%, Validation Accuracy: 92.68%, Test Accuracy: 95.78%
# --------------------------------------------------------------
# Epoch 9, Train Loss: 1.1724, Validation Loss: 3.9028, Test Loss: 4.1409, Train Accuracy: 94.92%, Validation Accuracy: 80.49%, Test Accuracy: 83.13%
# --------------------------------------------------------------
# Epoch 10, Train Loss: 0.9727, Validation Loss: 0.7397, Test Loss: 0.4317, Train Accuracy: 94.39%, Validation Accuracy: 94.51%, Test Accuracy: 94.58%
# --------------------------------------------------------------
# Best model saved at: models\best_model_trial_8.pt

# %% [markdown]
# **Visualize the accuracy and loss obtained for all trials**

# %%
train_accuracies = np.array([res['final_train_accuracy'] for res in results])
validation_accuracies = np.array([res['best_validation_accuracy'] for res in results])
test_accuracies = np.array([res['corresponding_test_accuracy'] for res in results])

train_losses = np.array([res['final_train_loss'] for res in results])
validation_losses = np.array([res['best_validation_loss'] for res in results])
test_losses = np.array([res['corresponding_test_loss'] for res in results])

trials = np.arange(1, len(results) + 1)

# Identifying the best trial based on validation accuracy
best_trial_acc = np.argmax(validation_accuracies) + 1
best_acc = validation_accuracies[best_trial_acc - 1]

# Plotting accuracies (training, validation, test)
plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
plt.plot(trials, train_accuracies, 'o-', label='Train Acc', color='blue')
plt.plot(trials, validation_accuracies, 's--', label='Valid Acc', color='orange')
plt.plot(trials, test_accuracies, '^-.', label='Test Acc', color='green')
plt.axvline(x=best_trial_acc, color='gray', linestyle='--', label=f'Best Trial #{best_trial_acc}')
plt.title('Accuracy Across Trials')
plt.xlabel('Trial')
plt.ylabel('Accuracy (%)')
plt.legend()

# Plotting losses (training, validation, and test)
plt.subplot(1, 2, 2)
plt.plot(trials, train_losses, 'o-', label='Train Loss', color='blue')
plt.plot(trials, validation_losses, 's--', label='Validation Loss', color='orange')
plt.plot(trials, test_losses, '^-.', label='Test Loss', color='green')
plt.axvline(x=best_trial_acc, color='gray', linestyle='--', label=f'Best Trial #{best_trial_acc}')
plt.title('Loss Across Trials')
plt.xlabel('Trial')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

print(f"Best Trial: {best_trial_acc} with Validation Accuracy: {best_acc}%")
# Out:
# Best Trial: 8 with Validation Accuracy: 94.51219512195122%
